# %%
# # Preamble

# ## Import colours

# In[1]:
# Lists of colors for plots

c0 = (0.76, 0.76, 0.76)
c1 = (1.00, 0.18, 0.33);
c2 = (1.00, 0.23, 0.19);
c3 = (1.00, 0.58, 0.00);
c4 = (1.00, 0.80, 0.00);
c5 = (0.30, 0.85, 0.39);
c6 = (0.35, 0.78, 0.98);
c7 = (0.20, 0.67, 0.86);
c8 = (0.00, 0.48, 1.00);
c9 = (0.35, 0.34, 0.84);
c10 = (0.00, 0.31, 0.57);
c11 = (0.12, 0.29, 0.69);
c12 = (0.17, 0.17, 0.42);
c13 = (1.00, 1.00, 1.00);
c14 = (0.77, 0.04, 0.00);

ios_colors=[c5, c1, c3, c7, c2, c6, c4, c9, c8]

def to_rgb_frac(vect):
    return (float(vect[0])/255, float(vect[1])/255, float(vect[2])/255)

color_list=list(map(to_rgb_frac, [(166,206,227),(178,223,138),(51,160,44),(31,120,180)]))

# Lists of colors for plots

def to_rgb_frac(vect):
    return (float(vect[0])/255, float(vect[1])/255, float(vect[2])/255)

rb_div_5=list(map(to_rgb_frac, [(202,0,32),
(244,165,130),
(247,247,247),
(146,197,222),
(5,113,176)]))

qualitative_10=list(map(to_rgb_frac, [(166,206,227),
(31,120,180),
(178,223,138),
(51,160,44),
(251,154,153),
(227,26,28),
(253,191,111),
(255,127,0),
(202,178,214),
(106,61,154)]))


# <img src="Qualitative_10.png">
# <img src="RB_DIV_5.png">



# ## Import packages

# In[2]:

#from __future__ import print_function
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# imported packages
get_ipython().run_line_magic('matplotlib', 'inline')
import datetime
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import matplotlib.ticker as plticker
import bisect
import copy
import json
import csv
import ast
import pylab as pl
import time
from scipy import integrate
from scipy.integrate import quad, dblquad
#import urllib2
#import io
#import os
#import re

# from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import interp1d
from scipy.special import expi
from sympy import DiracDelta
import time

#caroline's colour coding
#define the colors from colorbrewer2
orange1 = '#feedde'
orange2 = '#fdbe85'
orange3 = '#fd8d3c'
orange4 = '#e6550d'
orange5 = '#a63603'
blue1 = '#eff3ff'
blue2 = '#bdd7e7'
blue3 = '#6baed6'
blue4 = '#3182bd'
blue5 = '#08519c'
green1 = '#edf8e9'
green2 = '#bae4b3'
green3 = '#74c476'
green4 = '#31a354'
green5 = '#006d2c'
grey1 = '#f7f7f7'
grey2 = '#cccccc'
grey3 = '#969696'
grey4 = '#636363'
grey5 = '#252525'
purple1 = '#f2f0f7'
purple2 = '#cbc9e2'
purple3 = '#9e9ac8'
purple4 = '#756bb1'
purple5 = '#54278f'
red1 = '#fee5d9'
red2 = '#fcae91'
red3 = '#fb6a4a'
red4 = '#de2d26'
red5 = '#a50f15'
blue1 = '#08306b'
blue2 = '#08519c'
blue3 = '#2171b5'
blue4 = '#4292c6'
blue5 = '#6baed6'
blue6 = '#9ecae1'

# color_list = ['midnightblue', 'blue', 'royalblue', 'cornflowerblue', 'lightskyblue', 'powderblue']
# color_list = [blue1, blue2, blue3, blue4, blue5, blue6]
#color_list = [blue6, blue5, blue4, blue3, blue2, blue1]

# %%
from scipy import integrate
from scipy.integrate import quad

vector_of_first_mutant_60='vector_of_first_mutant_15000ppl_const_feeding_s_0.05_deterministic_age60.csv'
vector_of_first_mutant_90='vector_of_first_mutant_15000ppl_const_feeding_s_0.05_deterministic_age90.csv'
vector_of_first_mutant_120='vector_of_first_mutant_15000ppl_const_feeding_s_0.05_deterministic_age120.csv'

number_of_individuals=5000
s1=0.1
s2=0
u=10**-6
N=10**5
t=40
mu_1=10**-3
mu_2=10**-5
mu_lower=mu_1/100
mu_upper=1
s1=0.1
s2=0.15
s_min=0
s_max=0.2
s_range=np.linspace(s_min, s_max,100)
width=0.01    #cannot be too small as integration by sampling might miss the peak

plt.close('all')
f, ax1 = plt.subplots(3, 2, figsize=(10*2,15*2)) #width times height
plt.subplots_adjust(hspace = 0.7)  
font = {'weight' : 'normal','size'   : 16}
matplotlib.rc('font', **font)
VAF_lim=0.0009



def True_fitness_landscape(s):
    result=0
    if abs(s-s1)<width:
        result=mu_1/width
    elif abs(s-s2)<width:
        result=mu_2/width
    return result

fitness_landscape=[True_fitness_landscape(s) for s in s_range]
ax1[0][0].plot(s_range, fitness_landscape, color=qualitative_10[3], label='Mutation rates')
ax1[0][0].legend()
ax1[0][0].set_yscale('log')
ax1[0][0].set_xlabel('fitness')
ax1[0][0].set_ylabel('mutation rate')
ax1[0][0].set_title('True fitness landscape')
ax1[0][0].set_xlim(s_min,s_max)
ax1[0][0].set_ylim(mu_lower,mu_upper)
#ax1[0].set_xticks(major_ticks);                                                                                            
#ax1[0].set_xticklabels(major_tick_labels);


def Patient_VAF_spectrum(f,bin_positions_log_tp,densities_log_tp,n_bins): 
    l_spectrum_value=0
    for i in range(n_bins-1):
        if np.log(f)-binwidth/2<bin_positions_log_tp[i]<=np.log(f)+binwidth/2:
            l_spectrum_value=densities_log_tp[i]
    
    return l_spectrum_value

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n,bin_positions_log_tp,densities_log_tp,n_bins):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f,bin_positions_log_tp,densities_log_tp,n_bins)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum


def derivative_converted(a,bin_positions_log_tp,densities_log_tp,n_bins):
    h=5*np.log(N)/(n_bins-1)
    h=0.01
    return ((Infer_n_spectrum(np.exp(a+h),bin_positions_log_tp,densities_log_tp,n_bins))-\
            (Infer_n_spectrum(np.exp(a),bin_positions_log_tp,densities_log_tp,n_bins)))/h




first_mutant_60=[]
first_mutant_90=[]
first_mutant_120=[]
with open(vector_of_first_mutant_60) as data:
    reader = csv.reader(data,delimiter=',')
    next(reader, None)   #skips header
    for row in reader:
        try:            
            clone_size= float(row[1])
        except: # catch the error    
        #except IndexError: # catch the error
                pass # pass will basically ignore it
         # and execution will continue on to whatever comes
         # after the try/except block
        #print((row[1]))
        first_mutant_60.append(clone_size/(2*N))     
        
with open(vector_of_first_mutant_90) as data:
    reader = csv.reader(data,delimiter=',')
    next(reader, None)   #skips header
    for row in reader:
        try:            
            clone_size= float(row[1])
        except: # catch the error    
        #except IndexError: # catch the error
                pass # pass will basically ignore it
         # and execution will continue on to whatever comes
         # after the try/except block
        #print((row[1]))
        first_mutant_90.append(clone_size/(2*N))     
        
with open(vector_of_first_mutant_120) as data:
    reader = csv.reader(data,delimiter=',')
    next(reader, None)   #skips header
    for row in reader:
        try:            
            clone_size= float(row[1])
        except: # catch the error    
        #except IndexError: # catch the error
                pass # pass will basically ignore it
         # and execution will continue on to whatever comes
         # after the try/except block
        #print((row[1]))
        first_mutant_120.append(clone_size/(2*N))          
        

    
first_mutant_60=list(filter(lambda a: a != 0.0, first_mutant_60))
first_mutant_90=list(filter(lambda a: a != 0.0, first_mutant_90))
first_mutant_120=list(filter(lambda a: a != 0.0, first_mutant_120))

            
lfirst_mutant_60=np.log(np.array(first_mutant_60))  
lfirst_mutant_90=np.log(np.array(first_mutant_90))
lfirst_mutant_120=np.log(np.array(first_mutant_120))  
    
all_data=[first_mutant_60, first_mutant_90,first_mutant_120]
all_log_data=[lfirst_mutant_60, lfirst_mutant_90,lfirst_mutant_120]



major_ticks = np.log(np.array([10**-k for k in range(6)]))                                         
major_tick_labels= ["$10^{%s}$" % -k for k in range(6)]



n_bins=20   #is actually number of bins plus one
xmin=np.log(1/(2*N))
xmax=np.log(0.49)
binwidth=(xmax-xmin)/(n_bins-1)
ymin=0.01/(number_of_individuals*binwidth)
ymax=10**2

log_historam_data=[np.histogram(dat,bins=np.linspace(xmin, xmax, n_bins)) for dat in all_log_data]
densities_log=np.array([[c/(number_of_individuals*binwidth) for c in h[0]] for h in log_historam_data])
bin_positions_log=np.array([[(h[1][i]+h[1][i+1])/2 for i in range(len(h[1])-1)] for h in log_historam_data])

bin_positions_log_tp=bin_positions_log[2]
densities_log_tp=densities_log[2]

imported_VAF=[Patient_VAF_spectrum(np.exp(l),bin_positions_log_tp,densities_log_tp,n_bins) for l in bin_positions_log_tp]

ax1[1][0].bar(bin_positions_log_tp,densities_log_tp, width=binwidth, zorder=0, color=qualitative_10[8], edgecolor=qualitative_10[8], label='Patient VAF spectrum')
ax1[1][0].plot(bin_positions_log_tp,imported_VAF, zorder=0, color=qualitative_10[9], label='')
ax1[1][0].legend()
ax1[1][0].set_yscale('log')
ax1[1][0].set_xlabel('VAF')
ax1[1][0].set_ylabel('Logged Density')
ax1[1][0].set_title('Empirical VAF')
ax1[1][0].set_ylim(10**-6,10**3)                                                
ax1[1][0].set_xticks(major_ticks);                                                                                            
ax1[1][0].set_xticklabels(major_tick_labels);





log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent),bin_positions_log_tp,densities_log_tp,n_bins) for exponent in log_clone_size]

major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]

ax1[1][1].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Converted spectrum (still log binned)')
ax1[1][1].legend()
ax1[1][1].set_yscale('log')
ax1[1][1].set_xlabel('clone size')
ax1[1][1].set_ylabel('Logged Density')
ax1[1][1].set_title('Empirical VAF converted to n spectrum')
ax1[1][1].set_ylim(10**-6,10**3)                                                
ax1[1][1].set_xticks(major_ticks_for_n);                                                                                            
ax1[1][1].set_xticklabels(major_tick_labels_for_n);


first_derivative_of_logVAF_converted= [-derivative_converted(l,bin_positions_log_tp,densities_log_tp,n_bins) for l in log_clone_size]
ax1[1][1].plot(log_clone_size, first_derivative_of_logVAF_converted, color=qualitative_10[5], label='first derivative of VAF')
ax1[2][1].plot(log_clone_size, first_derivative_of_logVAF_converted, color=qualitative_10[5], label='first derivative of VAF')
ax1[2][1].legend()
ax1[2][1].set_yscale('log')
ax1[2][1].set_xlabel('clone size')
ax1[2][1].set_ylabel('log scale')
ax1[2][1].set_title('Magnitude of first derivative of converted spectrum')
ax1[2][1].set_ylim(10**-6,10**4)                                              
ax1[2][1].set_xticks(major_ticks_for_n);                                                                                            
ax1[2][1].set_xticklabels(major_tick_labels_for_n);

from scipy.optimize import fsolve, fmin, fminbound
from scipy.signal import find_peaks

#find maximum in derivative graph
#l_max=fmin(lambda l: derivative_converted(l,h=10**-5),1)
#l_max=fminbound(lambda l: derivative_converted(l,h=10**-5),0,2)   #constrains f(x) values
peak_possible_position=np.linspace(0,20,1000)
peaks,_=find_peaks([-derivative_converted(l,bin_positions_log_tp,densities_log_tp,n_bins)  for l in peak_possible_position])  #give the indices of the peaks in the list\
                                                                                                        #peak_possible_position
l_max_list=[peak_possible_position[i] for i in peaks]
inferred_phi=[np.exp(l_max) for l_max in l_max_list]
#n_max=np.exp(l_max)
initial_guess=0.05
#func= lambda s: inferred_phi*s+1-np.exp(s*t)   #python doesn't do well
#func2= lambda s: np.log(inferred_phi*s+1)-s*t
inferred_s=[fsolve(lambda s: np.log(phi*s+1)-s*t, initial_guess) for phi in inferred_phi ]
#inferred_s.remove(inferred_s[2])

#One peak
inferred_mutation_rate=[Infer_n_spectrum(np.exp(l_max),bin_positions_log_tp,densities_log_tp,n_bins)/\
                        (N*np.exp(-1))\
                        for l_max in l_max_list]


#Two peaks
# l_star_1=l_max_list[0]
# l_star_2=l_max_list[1]
# LHS=np.array([[N*np.exp(-1),N*np.exp(-np.exp(l_star_1-l_star_2))],[N*np.exp(-np.exp(l_star_2-l_star_1)),N*np.exp(-1)]])
# RHS=np.array([Infer_n_spectrum(np.exp(l_star_1)),Infer_n_spectrum(np.exp(l_star_2))])
# inferred_mutation_rate=np.linalg.solve(LHS, RHS)





#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[0][1].scatter(inferred_s, inferred_mutation_rate, label='Mutation rates', color="red", marker='P')
ax1[0][1].legend()
ax1[0][1].set_yscale('log')
ax1[0][1].set_xlabel('fitness')
ax1[0][1].set_ylabel('mutation rate')
ax1[0][1].set_title('Inferred fitness landscape')
ax1[0][1].set_xlim(s_min,s_max)
ax1[0][1].set_ylim(mu_lower,mu_upper)

# true_s_peaks=[s1,s2]
# true_phi=[(np.exp(s*t)-1)/s for s in true_s_peaks]
#plt.savefig('Inferring_fitness_const_s1_0.1_s2_0.15_u1_minus3_u2_minus5_wth_0.01.pdf', bbox_inches='tight')
#plt.savefig('Inferring_fitness_const_s_0.01_u_minus3__wth_0.01.pdf', bbox_inches='tight')
# Out:
# (1e-05, 1)

# %%
-derivative_converted(l_max,h=10**-4)/l_max*np.exp(l_max-np.exp(l_max)/((l_max*np.exp(l_max))/(1+l_max)))/(N/((l_max*np.exp(l_max))/(1+l_max)))
# Out:
# 6.74214548372068e-09

# %%
first_derivative_of_logVAF_converted
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %% [markdown]
#  l_max

# %%
# Out:
# 36787.94411714424

# %%
inferred_mutation_rate
# Out:
# array([4.16413726e-03, 1.90915290e-14])

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-b55df652bdf9> in <module>
# ----> 1 Infer_n_spectrum(1000, bin_positions_log_tp, densities_log_tp, n_bins)
#
# <ipython-input-52-5ad51f16cff1> in Infer_n_spectrum(n, bin_positions_log_tp, densities_log_tp, n_bins)
#      64 def Infer_n_spectrum(n,bin_positions_log_tp,densities_log_tp,n_bins):
#      65     f=n/(n+N)/2
# ---> 66     n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f,bin_positions_log_tp,densities_log_tp,n_bins)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
#      67     return n_spectrum
#      68
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
s=0.05
true_phi=(np.exp(s*t)-1)/s

# %%
l_max_list
# Out:
# [4.844844844844845, 7.867867867867868, 11.21121121121121]

# %%
len(peaks)
# Out:
# 2

# %%
# Out:
# No handles with labels found to put in legend.

# %%
def Patient_VAF_spectrum(f,bin_positions_log_tp,densities_log_tp,n_bins): 
    l_spectrum_value='huge'
    for i in range(n_bins-1):
        if abs(np.log(f)-binwidth/2)<bin_positions_log_tp[i]<=abs(np.log(f)+binwidth/2):
            l_spectrum_value=densities_log_tp[i]
    
    return l_spectrum_value

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n,bin_positions_log_tp,densities_log_tp,n_bins):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f,bin_positions_log_tp,densities_log_tp,n_bins)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum


def derivative_converted(a,bin_positions_log_tp,densities_log_tp,n_bins,h=binwidth):
    return ((Infer_n_spectrum(np.exp(a+h),bin_positions_log_tp,densities_log_tp,n_bins))-\
            (Infer_n_spectrum(np.exp(a),bin_positions_log_tp,densities_log_tp,n_bins)))/h

# %%
bin_positions_log_60=bin_positions_log[0]
densities_log_60=densities_log[0]
Infer_n_spectrum(np.exp(bin_positions_log[0][10]+1),bin_positions_log_60,densities_log_60, n_bins )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-a56ee0511eb8> in <module>
#       1 bin_positions_log_60=bin_positions_log[0]
#       2 densities_log_60=densities_log[0]
# ----> 3 Infer_n_spectrum(np.exp(bin_positions_log[0][10]+1),bin_positions_log_60,densities_log_60, n_bins )
#
# <ipython-input-104-51fa6517df25> in Infer_n_spectrum(n, bin_positions_log_tp, densities_log_tp, n_bins)
#      64 def Infer_n_spectrum(n,bin_positions_log_tp,densities_log_tp,n_bins):
#      65     f=n/(n+N)/2
# ---> 66     n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f,bin_positions_log_tp,densities_log_tp,n_bins)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
#      67     return n_spectrum
#      68
#
# TypeError: can't multiply sequence by non-int of type 'numpy.float64'

# %%
len(bin_positions_log[0])
# Out:
# 49

# %%
bin_positions_log_tp[3]-bin_positions_log_tp[2]
# Out:
# 0.23454536240107515

# %%
(bin_positions_log_tp[1]-bin_positions_log_tp[0])*n_bins
# Out:
# 11.727268120053846

# %%
binwidth
# Out:
# 0.2345453624010757

# %%
binwidth=(xmax-xmin)/(n_bins-1)

# %%
n_bins
# Out:
# 50
