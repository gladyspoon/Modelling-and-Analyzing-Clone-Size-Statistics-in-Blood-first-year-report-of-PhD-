# %%
# # Preamble

# ## Import colours

# In[1]:
# Lists of colors for plots

c0 = (0.76, 0.76, 0.76)
c1 = (1.00, 0.18, 0.33);
c2 = (1.00, 0.23, 0.19);
c3 = (1.00, 0.58, 0.00);
c4 = (1.00, 0.80, 0.00);
c5 = (0.30, 0.85, 0.39);
c6 = (0.35, 0.78, 0.98);
c7 = (0.20, 0.67, 0.86);
c8 = (0.00, 0.48, 1.00);
c9 = (0.35, 0.34, 0.84);
c10 = (0.00, 0.31, 0.57);
c11 = (0.12, 0.29, 0.69);
c12 = (0.17, 0.17, 0.42);
c13 = (1.00, 1.00, 1.00);
c14 = (0.77, 0.04, 0.00);

ios_colors=[c5, c1, c3, c7, c2, c6, c4, c9, c8]

def to_rgb_frac(vect):
    return (float(vect[0])/255, float(vect[1])/255, float(vect[2])/255)

color_list=list(map(to_rgb_frac, [(166,206,227),(178,223,138),(51,160,44),(31,120,180)]))

# Lists of colors for plots

def to_rgb_frac(vect):
    return (float(vect[0])/255, float(vect[1])/255, float(vect[2])/255)

rb_div_5=list(map(to_rgb_frac, [(202,0,32),
(244,165,130),
(247,247,247),
(146,197,222),
(5,113,176)]))

qualitative_10=list(map(to_rgb_frac, [(166,206,227),
(31,120,180),
(178,223,138),
(51,160,44),
(251,154,153),
(227,26,28),
(253,191,111),
(255,127,0),
(202,178,214),
(106,61,154)]))


# <img src="Qualitative_10.png">
# <img src="RB_DIV_5.png">



# ## Import packages

# In[2]:

#from __future__ import print_function
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

# imported packages
get_ipython().run_line_magic('matplotlib', 'inline')
import datetime
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import matplotlib.ticker as plticker
import bisect
import copy
import json
import csv
import ast
import pylab as pl
import time
from scipy import integrate
from scipy.integrate import quad, dblquad
#import urllib2
#import io
#import os
#import re

# from mpl_toolkits.mplot3d import Axes3D
from scipy.interpolate import interp1d
from scipy.special import expi
from sympy import DiracDelta
import time

#caroline's colour coding
#define the colors from colorbrewer2
orange1 = '#feedde'
orange2 = '#fdbe85'
orange3 = '#fd8d3c'
orange4 = '#e6550d'
orange5 = '#a63603'
blue1 = '#eff3ff'
blue2 = '#bdd7e7'
blue3 = '#6baed6'
blue4 = '#3182bd'
blue5 = '#08519c'
green1 = '#edf8e9'
green2 = '#bae4b3'
green3 = '#74c476'
green4 = '#31a354'
green5 = '#006d2c'
grey1 = '#f7f7f7'
grey2 = '#cccccc'
grey3 = '#969696'
grey4 = '#636363'
grey5 = '#252525'
purple1 = '#f2f0f7'
purple2 = '#cbc9e2'
purple3 = '#9e9ac8'
purple4 = '#756bb1'
purple5 = '#54278f'
red1 = '#fee5d9'
red2 = '#fcae91'
red3 = '#fb6a4a'
red4 = '#de2d26'
red5 = '#a50f15'
blue1 = '#08306b'
blue2 = '#08519c'
blue3 = '#2171b5'
blue4 = '#4292c6'
blue5 = '#6baed6'
blue6 = '#9ecae1'

# color_list = ['midnightblue', 'blue', 'royalblue', 'cornflowerblue', 'lightskyblue', 'powderblue']
# color_list = [blue1, blue2, blue3, blue4, blue5, blue6]
#color_list = [blue6, blue5, blue4, blue3, blue2, blue1]

# %%
def derivative(a,h=10**-3):
    return ((Patient_VAF_spectrum(np.exp(a+h)))-(Patient_VAF_spectrum(np.exp(a))))/h

def derivative_converted(a,h=10**-3):
    return ((Infer_n_spectrum(np.exp(a+h)))-(Infer_n_spectrum(np.exp(a))))/h




plt.close('all')
f, ax1 = plt.subplots(3, 2, figsize=(10*2,15*2)) #width times height
plt.subplots_adjust(hspace = 0.7)  
font = {'weight' : 'normal','size'   : 16}
matplotlib.rc('font', **font)
VAF_lim=0.0009


#t_min=50
#t_max=80
t=30


from scipy import integrate
from scipy.integrate import quad


N=10**5
u=10**-5
mu_lower=10**-10
mu_upper=10**-5
s_min=0
s_max=0.5
s_mean=0.05
s_range=np.linspace(s_min, s_max,100)



def True_fitness_landscape(s):
    result=u*np.exp(-s/s_mean)
    if s>s_max:
        result=0
    elif s<s_min:
        result=0
    return result

fitness_landscape=[True_fitness_landscape(s) for s in s_range]
ax1[0][0].plot(s_range, fitness_landscape, color=qualitative_10[3], label='Mutation rates')
ax1[0][0].legend()
ax1[0][0].set_yscale('log')
ax1[0][0].set_xlabel('fitness')
ax1[0][0].set_ylabel('mutation rate')
ax1[0][0].set_title('True fitness landscape')
ax1[0][0].set_xlim(s_min,s_max)
ax1[0][0].set_ylim(mu_lower,mu_upper)
#ax1[0].set_xticks(major_ticks);                                                                                            
#ax1[0].set_xticklabels(major_tick_labels);


#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    
    return l_spectrum

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]

major_ticks = np.log(np.array([10**-k for k in range(6)]))                                         
major_tick_labels= ["$10^{%s}$" % -k for k in range(6)]


ax1[1][0].bar(logged_frequency, Empirical_data, color=qualitative_10[7], label='Patient VAF spectrum')
ax1[1][0].legend()
ax1[1][0].set_yscale('log')
ax1[1][0].set_xlabel('VAF frequency')
ax1[1][0].set_ylabel('Logged Density')
ax1[1][0].set_title('Empirical VAF')
ax1[1][0].set_ylim(10**-6,10**3)                                                
ax1[1][0].set_xticks(major_ticks);                                                                                            
ax1[1][0].set_xticklabels(major_tick_labels);


conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))

s_maller_range=np.linspace(0,0.3,100)
Difference_in_magnitude= [(True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N))/True_fitness_landscape(s) for s in s_maller_range]

ax1[2][0].plot(s_maller_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
ax1[2][0].legend()
#ax1[2][0].set_yscale('log')
ax1[2][0].set_xlabel('fitness')
ax1[2][0].set_ylabel('Fractional difference')
ax1[2][0].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]

major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]

ax1[1][1].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Converted spectrum (still log binned)')
ax1[1][1].legend()
ax1[1][1].set_yscale('log')
ax1[1][1].set_xlabel('clone size')
ax1[1][1].set_ylabel('Logged Density')
ax1[1][1].set_title('Empirical VAF converted to n spectrum')
ax1[1][1].set_ylim(10**-6,10**3)                                                
ax1[1][1].set_xticks(major_ticks_for_n);                                                                                            
ax1[1][1].set_xticklabels(major_tick_labels_for_n);


first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]
ax1[2][1].plot(log_clone_size, first_derivative_of_logVAF_converted, color=qualitative_10[5], label='first derivative of VAF')
ax1[2][1].legend()
ax1[2][1].set_yscale('log')
ax1[2][1].set_xlabel('clone size')
ax1[2][1].set_ylabel('log scale')
ax1[2][1].set_title('Magnitude of first derivative of converted spectrum')
ax1[2][1].set_ylim(10**-6,10**4)                                              
ax1[2][1].set_xticks(major_ticks_for_n);                                                                                            
ax1[2][1].set_xticklabels(major_tick_labels_for_n);

from scipy.optimize import fsolve, fmin, fminbound
from scipy.signal import find_peaks

# #find maximum in derivative graph
# #l_max=fmin(lambda l: derivative_converted(l,h=10**-5),1)
# #l_max=fminbound(lambda l: derivative_converted(l,h=10**-5),0,2)   #constrains f(x) values
# peak_possible_position=np.linspace(0,20,1000)
# peaks,_=find_peaks([-derivative_converted(l,h=10**-5) for l in peak_possible_position])  #give the indices of the peaks in the list\
#                                                                                                         #peak_possible_position
# l_max_list=[peak_possible_position[i] for i in peaks]
# inferred_phi=[np.exp(l_max) for l_max in l_max_list]
# #n_max=np.exp(l_max)
# initial_guess=0.05
# #func= lambda s: inferred_phi*s+1-np.exp(s*t)   #python doesn't do well
# #func2= lambda s: np.log(inferred_phi*s+1)-s*t
# inferred_s=[fsolve(lambda s: np.log(phi*s+1)-s*t, initial_guess) for phi in inferred_phi ]
# #inferred_s.remove(inferred_s[2])

#One peak
# inferred_mutation_rate=[Infer_n_spectrum(np.exp(l_max))/\
#                         (N*np.exp(-1))\
#                         for l_max in l_max_list]


#Two peaks
# l_star_1=l_max_list[0]
# l_star_2=l_max_list[1]
# LHS=np.array([[N*np.exp(-1),N*np.exp(-np.exp(l_star_1-l_star_2))],[N*np.exp(-np.exp(l_star_2-l_star_1)),N*np.exp(-1)]])
# RHS=np.array([Infer_n_spectrum(np.exp(l_star_1)),Infer_n_spectrum(np.exp(l_star_2))])
# inferred_mutation_rate=np.linalg.solve(LHS, RHS)

conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range]


#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[0][1].plot(s_range, inferred_mutation_rate, label='Mutation rates', color="red", marker='P')
ax1[0][1].legend()
ax1[0][1].set_yscale('log')
ax1[0][1].set_xlabel('fitness')
ax1[0][1].set_ylabel('mutation rate')
ax1[0][1].set_title('Inferred fitness landscape')
ax1[0][1].set_xlim(s_min,s_max)
ax1[0][1].set_ylim(mu_lower,mu_upper)

# true_s_peaks=[s1,s2]
# true_phi=[(np.exp(s*t)-1)/s for s in true_s_peaks]
#plt.savefig('Inferring_fitness_const_upper_s_limitation_t_100_zoomed.pdf', bbox_inches='tight')
# #plt.savefig('Inferring_fitness_const_s_0.01_u_minus3__wth_0.01.pdf', bbox_inches='tight')
# Out:
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:94: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:94: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:97: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:171: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:171: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:172: RuntimeWarning: invalid value encountered in double_scalars
# (1e-10, 1e-05)

# %%
-derivative_converted(l_max,h=10**-4)/l_max*np.exp(l_max-np.exp(l_max)/((l_max*np.exp(l_max))/(1+l_max)))/(N/((l_max*np.exp(l_max))/(1+l_max)))
# Out:
# 6.74214548372068e-09

# %%
inferred_mutation_rate=[Infer_n_spectrum(np.exp(l_max))/\
                        (N*np.exp(-1))\
                        for l_max in l_max_list]

# %% [markdown]
#  l_max

# %%
l_max=l_max_list[0]
(N/(np.exp(l_max))*np.exp(l_max-1))
# Out:
# 36787.94411714424

# %%
inferred_mutation_rate
# Out:
# [nan,
#  -4.9360371475397286e-06,
#  -5.107459665568919e-06,
#  -5.281577157009517e-06,
#  -5.458002628831602e-06,
#  -5.636300377508054e-06,
#  -5.81598527524607e-06,
#  -5.996522781016891e-06,
#  -6.177329849201725e-06,
#  -6.357776822764532e-06,
#  -6.537190473668878e-06,
#  -6.714858342293352e-06,
#  -6.890034424811813e-06,
#  -7.061946340601906e-06,
#  -7.229804023089845e-06,
#  -7.39280991357911e-06,
#  -7.550170617951515e-06,
#  -7.701109889241202e-06,
#  -7.844882766818723e-06,
#  -7.980790503471357e-06,
#  -8.108195955689207e-06,
#  -8.226538941214213e-06,
#  -8.335350979051228e-06,
#  -8.434268800113238e-06,
#  -8.52304591483481e-06,
#  -8.601561575610744e-06,
#  -8.669826457552045e-06,
#  -8.727984450094306e-06,
#  -8.776310147768328e-06,
#  -8.81520174491263e-06,
#  -8.845169363691771e-06,
#  -8.866819028512401e-06,
#  -8.88083289505543e-06,
#  -8.887946588713303e-06,
#  -8.888924742332907e-06,
#  -8.88453608920759e-06,
#  -8.875529454186967e-06,
#  -8.862612076659302e-06,
#  -8.846431402511117e-06,
#  -8.827561352854432e-06,
#  -8.806493545185162e-06,
#  -8.783633615759893e-06,
#  -8.759302305990237e-06,
#  -8.733740580248081e-06,
#  -8.707117781848981e-06,
#  -8.679541656315156e-06,
#  -8.651069127351655e-06,
#  -8.6217167797406e-06,
#  -8.591470301729965e-06,
#  -8.56029241227377e-06,
#  -8.52812906802366e-06,
#  -8.494913998277283e-06,
#  -8.460571782858848e-06,
#  -8.425019772464871e-06,
#  -8.388169139089883e-06,
#  -8.349925375283376e-06,
#  -8.31018841238908e-06,
#  -8.268852538724044e-06,
#  -8.225806229625494e-06,
#  -8.180931910324457e-06,
#  -8.134105722877976e-06,
#  -8.085197304018999e-06,
#  -8.034069579605422e-06,
#  -7.980578584161431e-06,
#  -7.924573329282652e-06,
#  -7.86589571693541e-06,
#  -7.804380512300265e-06,
#  -7.73985538696954e-06,
#  -7.672141040704154e-06,
#  -7.6010514379300395e-06,
#  -7.526394144648076e-06,
#  -7.447970809370593e-06,
#  -7.3655777990176664e-06,
#  -7.279007015748086e-06,
#  -7.188046911036049e-06,
#  -7.092483738484154e-06,
#  -6.992103062482842e-06,
#  -6.8866915544493825e-06,
#  -6.776039107965247e-06,
#  -6.659941312468228e-06,
#  -6.538202293077938e-06,
#  -6.410637971254156e-06,
#  -6.277079756597813e-06,
#  -6.137378690186753e-06,
#  -5.991410062062679e-06,
#  -5.8390784967642885e-06,
#  -5.680323502634335e-06,
#  -5.515125465257851e-06,
#  -5.343512024737406e-06,
#  -5.165564791597028e-06,
#  -4.981426281573862e-06,
#  -4.7913069496867784e-06,
#  -4.595492157402476e-06,
#  -4.394348855295426e-06,
#  -4.188331731055735e-06,
#  -3.977988524128784e-06,
#  -3.7639641515577347e-06,
#  -3.5470032697287973e-06,
#  -3.3279508357344756e-06,
#  -3.1077502343357395e-06]

# %%
s=0.1
result=derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)
# Out:
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:65: RuntimeWarning: invalid value encountered in double_scalars

# %%
s=0.05
true_phi=(np.exp(s*t)-1)/s

# %%
result
# Out:
# nan

# %%
len(peaks)
# Out:
# 2

# %%
peaks
# Out:
# array([160, 359], dtype=int64)

# %%
np.log10(np.exp(l_max_list))
# Out:
# array([2.10408938, 3.4169716 , 4.86896716])

# %%
#Compare effectiveness of inference acorss different ages



from scipy import integrate
from scipy.integrate import quad



def derivative(a,h=10**-3):
    return ((Patient_VAF_spectrum(np.exp(a+h)))-(Patient_VAF_spectrum(np.exp(a))))/h

def derivative_converted(a,h=10**-3):
    return ((Infer_n_spectrum(np.exp(a+h)))-(Infer_n_spectrum(np.exp(a))))/h




plt.close('all')
f, ax1 = plt.subplots(2, 3, figsize=(32,20)) #width times height
plt.subplots_adjust(hspace = 0.2)  
font = {'weight' : 'normal','size'   : 25}
matplotlib.rc('font', **font)
density_upper=10**1
density_lower=10**-8





N=10**5
u=10**-5
mu_lower=10**-8
mu_upper=10**-3
s_min=0
s_max=0.5
s_mean=0.05
s_range=np.linspace(s_min, s_max,100)
s_range_margin=np.linspace(s_min-0.1, s_max+0.1,100)


# def True_fitness_landscape(s):
#     result=u*np.exp(-s/s_mean)
#     if s>s_max:
#         result=0
#     elif s<s_min:
#         result=0
#     return result

def True_fitness_landscape(s):
    result=u/(1+s/s_mean)
    #result=u*np.exp(-s/s_mean)
    if s>s_max:
        result=0
    elif s<s_min:
        result=0
    return result

fitness_landscape=[True_fitness_landscape(s) for s in s_range_margin]



t=10
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    
    return l_spectrum

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]


# ax1[0][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[0][1].legend()
# ax1[0][1].set_yscale('log')
# ax1[0][1].set_xlabel('fitness')
# ax1[0][1].set_ylabel('Fractional difference')
# ax1[0][1].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



ax1[1][0].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
ax1[1][0].legend()
ax1[1][0].set_yscale('log')
ax1[1][0].set_xlabel('clone size n')
ax1[1][0].set_ylabel('Logged Density')
ax1[1][0].set_title('Clone size spectrum at age 20')
ax1[1][0].set_ylim(density_lower,density_upper)                                                
ax1[1][0].set_xticks(major_ticks_for_n);                                                                                            
ax1[1][0].set_xticklabels(major_tick_labels_for_n);

first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[0][0].plot(s_range_margin, inferred_mutation_rate, label='inferred rates at age 20', color="red", marker='P')
ax1[0][0].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[0][0].legend()
ax1[0][0].set_yscale('log')
ax1[0][0].set_xlabel('s')
ax1[0][0].set_ylabel(r'$\mu$')
ax1[0][0].set_title('Inferred fitness landscape')
ax1[0][0].set_xlim(s_min-0.1,s_max+0.1)
ax1[0][0].set_ylim(mu_lower,mu_upper)






t=50
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    
    return l_spectrum

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]

# ax1[1][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[1][1].legend()
# ax1[1][1].set_yscale('log')
# ax1[1][1].set_xlabel('fitness')
# ax1[1][1].set_ylabel('Fractional difference')
# ax1[1][1].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



ax1[1][1].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
ax1[1][1].legend()
ax1[1][1].set_yscale('log')
ax1[1][1].set_xlabel('clone size n')
ax1[1][1].set_ylabel('Logged Density')
ax1[1][1].set_title('Clone size spectrum at age 50')
ax1[1][1].set_ylim(density_lower,density_upper)                                                
ax1[1][1].set_xticks(major_ticks_for_n);                                                                                            
ax1[1][1].set_xticklabels(major_tick_labels_for_n);


first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[0][1].plot(s_range_margin, inferred_mutation_rate, label='inferred rates at age 50', color="red", marker='P')
ax1[0][1].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[0][1].legend()
ax1[0][1].set_yscale('log')
ax1[0][1].set_xlabel('s')
ax1[0][1].set_ylabel(r'$\mu$')
ax1[0][1].set_title('Inferred fitness landscape')
ax1[0][1].set_xlim(s_min-0.1,s_max+0.1)
ax1[0][1].set_ylim(mu_lower,mu_upper)






t=100
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    
    return l_spectrum

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]

# ax1[2][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[2][1].legend()
# ax1[2][1].set_yscale('log')
# ax1[2][1].set_xlabel('fitness')
# ax1[2][1].set_ylabel('Fractional difference')
# ax1[2][1].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



ax1[1][2].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
ax1[1][2].legend()
ax1[1][2].set_yscale('log')
ax1[1][2].set_xlabel('clone size n')
ax1[1][2].set_ylabel('Logged Density')
ax1[1][2].set_title('Clone size spectrum at age 100')
ax1[1][2].set_ylim(density_lower,density_upper)                                                
ax1[1][2].set_xticks(major_ticks_for_n);                                                                                            
ax1[1][2].set_xticklabels(major_tick_labels_for_n);



first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


ax1[0][2].plot(s_range_margin, inferred_mutation_rate, label='inferred rates at age 100', color="red", marker='P')
ax1[0][2].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[0][2].legend()
ax1[0][2].set_yscale('log')
ax1[0][2].set_xlabel('s')
ax1[0][2].set_ylabel(r'$\mu$')
ax1[0][2].set_title('Inferred fitness landscape')
ax1[0][2].set_xlim(s_min-0.1,s_max+0.1)
ax1[0][2].set_ylim(mu_lower,mu_upper)
#plt.savefig('Accuracy_of_inference_beneficial_continuous_power_law_landscape.pdf', bbox_inches='tight')
plt.savefig('Inferring_fitness_const_s_power_DFE.pdf', bbox_inches='tight')
# Out:
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:89: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:89: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:92: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:176: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:176: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:179: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:263: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:263: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:266: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:241: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:241: RuntimeWarning: invalid value encountered in double_scalars

# %%
s_mean
# Out:
# 0.05

# %%
# vary VAF limit

#Compare effectiveness of inference acorss different ages



from scipy import integrate
from scipy.integrate import quad



def derivative(a,h=10**-3):
    return ((Patient_VAF_spectrum(np.exp(a+h)))-(Patient_VAF_spectrum(np.exp(a))))/h

def derivative_converted(a,h=10**-3):
    return ((Infer_n_spectrum(np.exp(a+h)))-(Infer_n_spectrum(np.exp(a))))/h




plt.close('all')
f, ax1 = plt.subplots(2, 3, figsize=(32,20)) #width times height
plt.subplots_adjust(hspace = 0.2)  
font = {'weight' : 'normal','size'   : 25}
matplotlib.rc('font', **font)
density_upper=10**1
density_lower=10**-6





N=10**5
u=10**-5
mu_lower=10**-10
mu_upper=10**-3
s_min=0
s_max=0.5
s_mean=0.05
s_range=np.linspace(s_min, s_max,100)
s_range_margin=np.linspace(s_min-0.1, s_max+0.1,100)


def True_fitness_landscape(s):
    result=u*np.exp(-s/s_mean)
    if s>s_max:
        result=0
    elif s<s_min:
        result=0
    return result

# def True_fitness_landscape(s):
#     result=u/(1+s/s_mean)
#     if s>s_max:
#         result=0
#     elif s<s_min:
#         result=0
#     return result

fitness_landscape=[True_fitness_landscape(s) for s in s_range_margin]



t=50
VAF_lim=0.001
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    end_result= l_spectrum
    if f<VAF_lim:
        end_result=0
    return end_result

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]


# ax1[0][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[0][1].legend()
# ax1[0][1].set_yscale('log')
# ax1[0][1].set_xlabel('fitness')
# ax1[0][1].set_ylabel('Fractional difference')
# ax1[0][1].set_title('Accuracy of inferred mutation rates')
# #ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



# ax1[0][2].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
# ax1[0][2].legend()
# ax1[0][2].set_yscale('log')
# ax1[0][2].set_xlabel('clone size n')
# ax1[0][2].set_ylabel('Logged Density')
# ax1[0][2].set_title('VAF limit 1 % \n Empirical VAF')
# ax1[0][2].set_ylim(density_lower,density_upper)                                                
# ax1[0][2].set_xticks(major_ticks_for_n);                                                                                            
# ax1[0][2].set_xticklabels(major_tick_labels_for_n);

first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[0][0].plot(s_range_margin, inferred_mutation_rate, label='inferred rates', color="red", marker='P')
ax1[0][0].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[0][0].legend()
ax1[0][0].set_yscale('log')
ax1[0][0].set_xlabel('s')
ax1[0][0].set_ylabel('exponential decay \n' r'$\mu$')
ax1[0][0].set_title('VAF limit 1 %')
ax1[0][0].set_xlim(s_min-0.1,s_max+0.1)
ax1[0][0].set_ylim(mu_lower,mu_upper)






VAF_lim=0.05
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    end_result= l_spectrum
    if f<VAF_lim:
        end_result=0
    return end_result

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]

# ax1[1][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[1][1].legend()
# ax1[1][1].set_yscale('log')
# ax1[1][1].set_xlabel('fitness')
# ax1[1][1].set_ylabel('Fractional difference')
# ax1[1][1].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



# ax1[1][2].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
# ax1[1][2].legend()
# ax1[1][2].set_yscale('log')
# ax1[1][2].set_xlabel('clone size n')
# ax1[1][2].set_ylabel('Logged Density')
# ax1[1][2].set_title('VAF limit 5 % \n Empirical VAF')
# ax1[1][2].set_ylim(density_lower,density_upper)                                                
# ax1[1][2].set_xticks(major_ticks_for_n);                                                                                            
# ax1[1][2].set_xticklabels(major_tick_labels_for_n);


first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[0][1].plot(s_range_margin, inferred_mutation_rate, label='inferred rates', color="red", marker='P')
ax1[0][1].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[0][1].legend()
ax1[0][1].set_yscale('log')
ax1[0][1].set_xlabel('s')
ax1[0][1].set_ylabel(r'$\mu$')
ax1[0][1].set_title('VAF limit 5 %')
ax1[0][1].set_xlim(s_min-0.1,s_max+0.1)
ax1[0][1].set_ylim(mu_lower,mu_upper)






VAF_lim=0.1
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    end_result= l_spectrum
    if f<VAF_lim:
        end_result=0
    return end_result

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]

# ax1[2][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[2][1].legend()
# ax1[2][1].set_yscale('log')
# ax1[2][1].set_xlabel('fitness')
# ax1[2][1].set_ylabel('Fractional difference')
# ax1[2][1].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



# ax1[2][2].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
# ax1[2][2].legend()
# ax1[2][2].set_yscale('log')
# ax1[2][2].set_xlabel('clone size n')
# ax1[2][2].set_ylabel('Logged Density')
# ax1[2][2].set_title('VAF limit 10 % \n Empirical VAF')
# ax1[2][2].set_ylim(density_lower,density_upper)                                                
# ax1[2][2].set_xticks(major_ticks_for_n);                                                                                            
# ax1[2][2].set_xticklabels(major_tick_labels_for_n);



first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


ax1[0][2].plot(s_range_margin, inferred_mutation_rate, label='inferred rates', color="red", marker='P')
ax1[0][2].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[0][2].legend()
ax1[0][2].set_yscale('log')
ax1[0][2].set_xlabel('s')
ax1[0][2].set_ylabel(r'$\mu$')
ax1[0][2].set_title('VAF limit 10 %')
ax1[0][2].set_xlim(s_min-0.1,s_max+0.1)
ax1[0][2].set_ylim(mu_lower,mu_upper)


def True_fitness_landscape(s):
    result=u/(1+s/s_mean)
    if s>s_max:
        result=0
    elif s<s_min:
        result=0
    return result




fitness_landscape=[True_fitness_landscape(s) for s in s_range_margin]
mu_lower=10**-8


t=50
VAF_lim=0.001
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    end_result= l_spectrum
    if f<VAF_lim:
        end_result=0
    return end_result

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]


# ax1[0][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[0][1].legend()
# ax1[0][1].set_yscale('log')
# ax1[0][1].set_xlabel('fitness')
# ax1[0][1].set_ylabel('Fractional difference')
# ax1[0][1].set_title('Accuracy of inferred mutation rates')
# #ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



# ax1[0][2].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
# ax1[0][2].legend()
# ax1[0][2].set_yscale('log')
# ax1[0][2].set_xlabel('clone size n')
# ax1[0][2].set_ylabel('Logged Density')
# ax1[0][2].set_title('VAF limit 1 % \n Empirical VAF')
# ax1[0][2].set_ylim(density_lower,density_upper)                                                
# ax1[0][2].set_xticks(major_ticks_for_n);                                                                                            
# ax1[0][2].set_xticklabels(major_tick_labels_for_n);

first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[1][0].plot(s_range_margin, inferred_mutation_rate, label='inferred rates', color="red", marker='P')
ax1[1][0].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[1][0].legend()
ax1[1][0].set_yscale('log')
ax1[1][0].set_xlabel('s')
ax1[1][0].set_ylabel('power-law \n' r'$\mu$')
#ax1[1][0].set_title('Inferred fitness landscape (power-law)')
ax1[1][0].set_xlim(s_min-0.1,s_max+0.1)
ax1[1][0].set_ylim(mu_lower,mu_upper)






VAF_lim=0.05
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    end_result= l_spectrum
    if f<VAF_lim:
        end_result=0
    return end_result

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]

# ax1[1][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[1][1].legend()
# ax1[1][1].set_yscale('log')
# ax1[1][1].set_xlabel('fitness')
# ax1[1][1].set_ylabel('Fractional difference')
# ax1[1][1].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



# ax1[1][2].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
# ax1[1][2].legend()
# ax1[1][2].set_yscale('log')
# ax1[1][2].set_xlabel('clone size n')
# ax1[1][2].set_ylabel('Logged Density')
# ax1[1][2].set_title('VAF limit 5 % \n Empirical VAF')
# ax1[1][2].set_ylim(density_lower,density_upper)                                                
# ax1[1][2].set_xticks(major_ticks_for_n);                                                                                            
# ax1[1][2].set_xticklabels(major_tick_labels_for_n);


first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


#ax1[0][1].plot([inferred_s], Inferred_fitness_landscape, label='Mutation rates'\
#               , marker='o', markersize=3, color="red")
ax1[1][1].plot(s_range_margin, inferred_mutation_rate, label='inferred rates', color="red", marker='P')
ax1[1][1].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[1][1].legend()
ax1[1][1].set_yscale('log')
ax1[1][1].set_xlabel('s')
ax1[1][1].set_ylabel(r'$\mu$')
#ax1[1][1].set_title('Inferred fitness landscape (power-law)')
ax1[1][1].set_xlim(s_min-0.1,s_max+0.1)
ax1[1][1].set_ylim(mu_lower,mu_upper)






VAF_lim=0.1
#returns l_spectrum (log binnning)
def Patient_VAF_spectrum(f): 
    n_tilde=lambda s: (np.exp(s*t)-1)/s
    f_spectrum= lambda s: (2*N/(1-2*f)/f)*np.exp(-(2*N*f/(1-2*f))/((np.exp(s*t)-1)/s))*True_fitness_landscape(s)
    result = integrate.quad(f_spectrum, s_min,s_max)[0]
    l_spectrum= result*f
    end_result= l_spectrum
    if f<VAF_lim:
        end_result=0
    return end_result

#removes artificial reduction near 50% VAF
def Infer_n_spectrum(n):
    f=n/(n+N)/2
    n_spectrum= ((1-2*f)**2/(2*N))*Patient_VAF_spectrum(f)/f*n     #((1-f)**2/N) from changing f to n;   still log binned
    return n_spectrum



logged_frequency=np.linspace(np.log(10**-5),np.log(0.499),100)
Empirical_data = [Patient_VAF_spectrum(np.exp(l)) for l in logged_frequency]






conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))


Difference_in_magnitude= [abs((True_fitness_landscape(s)-conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N)))/True_fitness_landscape(s) for s in s_range]

# ax1[2][1].plot(s_range, Difference_in_magnitude, color=qualitative_10[9], label='difference in rates')
# ax1[2][1].legend()
# ax1[2][1].set_yscale('log')
# ax1[2][1].set_xlabel('fitness')
# ax1[2][1].set_ylabel('Fractional difference')
# ax1[2][1].set_title('Accuracy of inferred mutation rates')
#ax1[2][0].set_ylim(10**-6,10**4)    
#ax1[2].set_xlim(s_min,s_max)                                                
#ax1[2][0].set_xticks(major_ticks);                                                                                            
#ax1[2][0].set_xticklabels(major_tick_labels);



log_clone_size=np.linspace(np.log(1),np.log(1*N),10**3)
Empirical_data_converted_to_n=[Infer_n_spectrum(np.exp(exponent)) for exponent in log_clone_size]
major_ticks_for_n = np.log(np.array([10**k for k in range(7)]))                                         
major_tick_labels_for_n= ["$10^{%s}$" % k for k in range(7)]



# ax1[2][2].bar(log_clone_size, Empirical_data_converted_to_n, color=qualitative_10[7], label='Log-binned')
# ax1[2][2].legend()
# ax1[2][2].set_yscale('log')
# ax1[2][2].set_xlabel('clone size n')
# ax1[2][2].set_ylabel('Logged Density')
# ax1[2][2].set_title('VAF limit 10 % \n Empirical VAF')
# ax1[2][2].set_ylim(density_lower,density_upper)                                                
# ax1[2][2].set_xticks(major_ticks_for_n);                                                                                            
# ax1[2][2].set_xticklabels(major_tick_labels_for_n);



first_derivative_of_logVAF_converted= [-derivative_converted(l,h=10**-5) for l in log_clone_size]



conversion_factor=lambda s: (1/s-t*np.exp(s*t)/(np.exp(s*t)-1))
inferred_mutation_rate = [conversion_factor(s)*derivative_converted(np.log((np.exp(s*t)-1)/s),h=10**-5)*1/(2*N) for s in s_range_margin]


ax1[1][2].plot(s_range_margin, inferred_mutation_rate, label='inferred rates', color="red", marker='P')
ax1[1][2].plot(s_range_margin, fitness_landscape, color=qualitative_10[3], label='true rates')
ax1[1][2].legend()
ax1[1][2].set_yscale('log')
ax1[1][2].set_xlabel('s')
ax1[1][2].set_ylabel(r'$\mu$')
#ax1[1][2].set_title('Inferred fitness landscape (power-law)')
ax1[1][2].set_xlim(s_min-0.1,s_max+0.1)
ax1[1][2].set_ylim(mu_lower,mu_upper)
#plt.savefig('Accuracy_of_inference_vary_VAF_expo_landscape.pdf', bbox_inches='tight')
plt.savefig('Inferring_fitness_vary_VAF_lim.pdf', bbox_inches='tight')
# Out:
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:93: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:93: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:96: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:182: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:182: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:185: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:271: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:271: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:274: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:371: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:371: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:374: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:460: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:460: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:463: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:549: RuntimeWarning: divide by zero encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:549: RuntimeWarning: invalid value encountered in double_scalars
# C:\Users\chickchick\Anaconda3\lib\site-packages\ipykernel_launcher.py:552: RuntimeWarning: invalid value encountered in double_scalars
